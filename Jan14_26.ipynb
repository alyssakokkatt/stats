# %% [markdown]
# <a href="https://colab.research.google.com/github/alyssakokkatt/stats/blob/main/Jan14_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
ad_expense = [10,20,50, 41]
sales = [500,750,1140,1298]
plt.plot(ad_expense, sales)
#this si a comment
